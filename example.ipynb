# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2

from DataGenerator import generate_image, cut_image, show_boxes

# %%
data = pd.read_csv('data/train.csv')

X = np.asarray(data.drop(columns=['label']))
Y = np.asarray(data['label'])

del(data)

# %%
X.shape
# Out:
# (42000, 784)

# %%
def show(n): plt.imshow(X[n].reshape(28,28), cmap='gray')

# %%
show(10)

# %%
new_im = cut_image(10, X, Y)

# %%
plt.imshow(new_im, cmap='gray')

# %%
image, x_vals, y_vals = generate_image(X,Y)
plt.imshow(image, cmap='gray')
print('Bounding_boxes:')
print(x_vals)
print('Values:')
print(y_vals)
# Out:
# Bounding_boxes:
# [(9, 22, 20, 16), (59, 26, 20, 12), (93, 29, 20, 14), (127, 28, 20, 12), (175, 22, 20, 17)]
# Values:
# [6, 9, 9, 4, 0]

# %%
show_boxes(image, x_vals)
